# %% [markdown]
# # Applied Data Science and Machine Learning
# ## A program by IIT Madras and TalentSprint
# ### Module 2 Mini Project: Sentiment Analysis using linear classifiers and unsupervised clustering.

# %% [markdown]
# ## Learning Objectives
#
# At the end of the mini project, you will be able to -
#
# * use a real world dataset.
# * undertake several important steps like cleaning the data and normalizing the data points.
# * do sentiment classification.
# * compare between different types of classification methods and their pros and cons.
# * compare between supervised and unsupervised (clustering) techniques.

# %% [markdown]
# ### Goal of the project
# The goal of this project is to train linear classification models that can recognize the sentiment of the reviewer. In this project we will be dealing with only positive and negative sentiments (binary classification).
#
# **Disclaimer**:
# There are multiple ways to solve this problem, as there is no unique formula to solve.
# This is just one such approach.

# %% [markdown]
# **Packages used:**
# * `Pandas` for data frames and easy to read csv files
# * `Numpy` for array and matrix mathematics functions
# * `Matplotlib` and `Seaborn` for visualization
# *  `sklearn` for the metrics and pre-processing
# * `scipy` for helper functions required at various stages of the project.
# * `warnings` is used to supress warnings from different libraries used in the project.

# %% [markdown]
# ### Importing the packages

# %%
# Importing standard libraries
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import pandas as pd
import scipy
import math
import random

# Importing linear classification algorithms
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn import tree
from sklearn.ensemble import VotingClassifier, RandomForestClassifier
from sklearn.cluster import KMeans

# Importing the clustering algorithms
from sklearn.cluster import MiniBatchKMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.mixture import GaussianMixture

# Importing preprocessing functions
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD

# Importing metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

# Suppressing warningsyy
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Downloading a dataset containing amazon review information along with ratings

# %%
#@title Download Dataset
# !wget https://cdn.iisc.talentsprint.com/ADSMI/Datasets/amazon_reviews.zip
# !unzip "amazon_reviews.zip"
# Out:
# --2026-09-13 09:16:19--  https://cdn.iisc.talentsprint.com/ADSMI/Datasets/amazon_reviews.zip
# Resolving cdn.iisc.talentsprint.com (cdn.iisc.talentsprint.com)... 13.207.235.150, 13.206.13.226
# Connecting to cdn.iisc.talentsprint.com (cdn.iisc.talentsprint.com)|13.207.235.150|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29949034 (29M) [application/zip]
# Saving to: ‘amazon_reviews.zip’
#
# amazon_reviews.zip  100%[===================>]  28.56M  8.59MB/s    in 3.3s
#
# 2026-09-13 09:16:23 (8.59 MB/s) - ‘amazon_reviews.zip’ saved [29949034/29949034]
#
# Archive:  amazon_reviews.zip
#   inflating: amazon_reviews.csv

# %% [markdown]
# ## How does the dataset look like?
# Lets use a standard dataset from Amazon which contains reviews and ratings from the customer. The original dataset has three features: name(name of the products), review(Customer reviews of the products), and rating(rating of the customer of a product ranging from 1 to 5). The review column will be the input column and the rating column will be used to understand the sentiments of the review. Here are some important data preprocessing steps:
# The dataset has about 183,500 rows of data. There are 1147 null values which will be removed.
# As the dataset is pretty big, it takes a lot of time to run some machine learning algorithms. We will use 30% of the data in this project which is still 54,000+ data points! The sample will be representative of the whole dataset.
# If the rating is 1 and 2 that will be considered a negative review. And if the review is 3, 4, and 5, the review will be considered as a  positive review. We add a new column named ‘sentiments’ to the dataset that will use 1 for the positive reviews and 0 for the negative reviews. We read and display the contents of the dataset down below.

# %% [markdown]
# **Exercise 1**: Load the data and perform the following (2 points)
# - Exploratory Data Analysis
# - Preprocessing
#
#
# **Hints:**
#
# - checking for the number of rows and columns
# - summary of the dataset
# - statistical description of the features
# - check for the duplicate values
# - Show the top 5 and the last 5 rows of the data
# - check for the null values, and handle them if *any*

# %% [markdown]
# For Exercises, 2 to 9, use sklearn library to model, fit, train and see the metrics [Accuracy and F1_score]. Writing your own custom functions is  not required.
#
#
# 1.   **Exercise 1**: Load the data and perform the following : (2 point)
#       - Exploratory Data Analysis
#       - Preprocessing
# 2.   **Exercise 2**: **Implementation using K-Nearest Neighbor (KNN) Classifier**:  (2 point)
#
# 3.   **Exercise 3**: **Implementation using Support Vector Machines (SVM) Classifier**:
#       - First Reduce the features using PCA
#       - use Hard-Margin Classifier
#       - use Soft-Margin Classifier
#       - use Kernel SVM Classifier
# 4.   **Exercise 4**: **Implementation using Decision Trees**:  (2 point)
# 5.   **Exercise 5**: **Implementation using Ensemble Classifier**:  (1 point)
#       - use LogisticRegression, KNN, SVM, and VotingClassifier as the weak classifiers
#
# 6.   **Exercise 6**: **Implementation using Clustering**: (2 point)
#       - k Means Clustering
#
# 7.   **Exercise 7**: **Test your own sentence**: (1 point)
#       - Input your sentences ( One for positive and negative each)
#       - Print the output sentiment.

# %% [markdown]
# **Sample code using Logistic Regression**
#
# The logistic function, more popularly called the sigmoid function was to describe properties of population growth in ecology, rising quickly and maxing out at the carrying capacity of the environment.
#
# It’s an S-shaped curve that can take any real-valued number and map it into a value between 0 and 1, but never exactly at those limits.
#
# $\frac{1}{ (1 + e^{-value})}$
#
# Where $e$ is the base of the natural logarithms and value is the actual numerical value that you want to transform. Below is a plot of the numbers between $-5$ and $5$ transformed into the range $0$ and $1$ using the logistic function.

# %%
# Logistic regression model is defined
#logistic_regression = LogisticRegression()

# Training the logistic regression classifier
#logistic_regression.fit(X_train_vec, y_train)

# Calculating accuracy on the logistic regression classifier
# The accuracy is within 0 and 1 in this snippet
#lr_score = logistic_regression.score(X_test_vec, y_test)
#print("Accuracy of the sentiment classification using the Logistic Regression based classifier: ", lr_score)

# Predicting on the test set
#y_pred_lr = logistic_regression.predict(X_test_vec)

# F1 score calculation
#lr_f1_score = f1_score(y_pred_lr, y_test)

#print ("F1 Score for sentiment classification using the Logistic Regression based classifier: ", lr_f1_score)

# %% [markdown]
# **Exercise 1**: Load the data and perform the following: (2 point)
#
# - Exploratory Data Analysis (Use Pandas, Seaborn)
# - Preprocessing (Use Pandas)
#
# **Hints:**
#
# - checking for the number of rows and columns
# - summary of the dataset
# - statistical description of the features
# - check for the duplicate values
# - Show the top 5 and the last 5 rows of the data
# - check for the null values, and handle them if *any*

# %%
df = pd.read_csv('amazon_reviews.csv')
df.shape
# Out:
# (183531, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183531 entries, 0 to 183530
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   name    183213 non-null  object
#  1   review  182702 non-null  object
#  2   rating  183531 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 4.2+ MB

# %%
df.describe()
# Out:
#               rating
# count  183531.000000
# mean        4.120448
# std         1.285017
# min         1.000000
# 25%         4.000000
# 50%         5.000000
# 75%         5.000000
# max         5.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(62)

# %%
df[df.duplicated()]
# Out:
#                                                      name review  rating
# 1689    Graco TotBloc Pack 'N Play with Carry Bag, Bug...    NaN       5
# 10405                  Wimmer-Ferguson Infant Stim-Mobile    NaN       5
# 11611          Fisher-Price Booster Seat, Blue/Green/Gray    NaN       5
# 13377     North States Superyard Play Yard, Grey, 6 Panel    NaN       5
# 13458     North States Superyard Play Yard, Grey, 6 Panel    NaN       5
# ...                                                   ...    ...     ...
# 157744   Britax Marathon 70-G3 Convertible Car Seat, Onyx    NaN       5
# 157762   Britax Marathon 70-G3 Convertible Car Seat, Onyx    NaN       5
# 158215    Jumping Beans&reg; Olivia Owl Hooded Bath Towel    NaN       5
# 160707  myBaby Soundspa Lullaby Sound Machine and Proj...    NaN       5
# 166707  Hooded HELLO KITTY Fleece Throw! Pink White Bo...    NaN       5
#
# [62 rows x 3 columns]

# %%
df.head()
# Out:
#                                                 name  \
# 0                           Planetwise Flannel Wipes
# 1                              Planetwise Wipe Pouch
# 2                Annas Dream Full Quilt with 2 Shams
# 3  Stop Pacifier Sucking without tears with Thumb...
# 4  Stop Pacifier Sucking without tears with Thumb...
#
#                                               review  rating
# 0  These flannel wipes are OK, but in my opinion ...       3
# 1  it came early and was not disappointed. i love...       5
# 2  Very soft and comfortable and warmer than it l...       5
# 3  This is a product well worth the purchase.  I ...       5
# 4  All of my kids have cried non-stop when I trie...       5

# %%
df.tail()
# Out:
#                                                      name  \
# 183526  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183527  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183528   Abstract 2 PK Baby / Toddler Training Cup (Pink)
# 183529  Baby Food Freezer Tray - Bacteria Resistant, B...
# 183530  Best 2 Pack Baby Car Shade for Kids - Window S...
#
#                                                    review  rating
# 183526  Such a great idea! very handy to have and look...       5
# 183527  This product rocks!  It is a great blend of fu...       5
# 183528  This item looks great and cool for my kids.......       5
# 183529  I am extremely happy with this product. I have...       5
# 183530  I love this product very mush . I have bought ...       5

# %% [markdown]
# There are 1147 null values which will be removed.
# 318+829 = 1147

# %%
df.isnull().sum()
# Out:
# name      318
# review    829
# rating      0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                                      name review  rating
# 38           SoftPlay Twinkle Twinkle Elmo A Bedtime Book    NaN       5
# 58                              Our Baby Girl Memory Book    NaN       5
# 721     Summer Infant, Ultimate Training Pad - Twin Ma...    NaN       5
# 1050                Safety 1st Deluxe 4-in-1 Bath Station    NaN       1
# 1183             Northstate Superyard Playgate Light Gray    NaN       5
# ...                                                   ...    ...     ...
# 183143  The #1 Baby Nasal Aspirator - Free Carry Case,...    NaN       5
# 183220  Dwinguler Eco-friendly Kid's Playmat - Sound P...    NaN       5
# 183230  Graco Benton 5-in-1 Convertible Fixed-Side Cri...    NaN       5
# 183241  Merry Muscles Ergonomic Jumper Exerciser Baby ...    NaN       5
# 183344  SnappyNips Bottle Caps for converting Glass Be...    NaN       5
#
# [1147 rows x 3 columns]

# %%
df[df["name"].isnull()]
# Out:
#        name                                             review  rating
# 10551   NaN  If you're searching for an elegant, inexpensiv...       4
# 10552   NaN  This item looks very good and I was going to o...       1
# 10553   NaN  Bought this item for my child's crib but found...       2
# 22234   NaN  Baby sleeps in this every single night. The ve...       5
# 22235   NaN  The hospital that we delivered at sent a micro...       5
# ...     ...                                                ...     ...
# 177491  NaN  I got this for my 5 month old. Have had it abo...       4
# 180213  NaN  A very nice and accurate scale for a reasonabl...       5
# 180565  NaN  It's a nice size and very light and soft, but ...       3
# 180566  NaN  The pillow is just okay.  I wish the pillow ha...       3
# 183072  NaN  does not come with pole that attaches to crib ...       1
#
# [318 rows x 3 columns]

# %%
df = df.dropna(how='any')

# %%
df.head()
# Out:
#                                                 name  \
# 0                           Planetwise Flannel Wipes
# 1                              Planetwise Wipe Pouch
# 2                Annas Dream Full Quilt with 2 Shams
# 3  Stop Pacifier Sucking without tears with Thumb...
# 4  Stop Pacifier Sucking without tears with Thumb...
#
#                                               review  rating
# 0  These flannel wipes are OK, but in my opinion ...       3
# 1  it came early and was not disappointed. i love...       5
# 2  Very soft and comfortable and warmer than it l...       5
# 3  This is a product well worth the purchase.  I ...       5
# 4  All of my kids have cried non-stop when I trie...       5

# %%
df.isnull().sum()
# Out:
# name      0
# review    0
# rating    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182384 entries, 0 to 183530
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   name    182384 non-null  object
#  1   review  182384 non-null  object
#  2   rating  182384 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 5.6+ MB

# %% [markdown]
# Select only 30% of data . We will use 30% of the data in this project which is still 54,000+ data points! The sample will be representative of the whole dataset.

# %%
df = df.sample(frac=0.30, random_state=42)

# %%
df["sentiment"] = pd.cut(
    df["rating"],
    bins=[0, 2, 5],
    labels=[0, 1]
)

# %%
df.head()
# Out:
#                                                      name  \
# 181948  Freemie Cups for Medela pumps - Set of Two Cup...
# 153948  Re-Play Divided Plates, Aqua, Green, Orange, 3...
# 170450  C.R. Gibson Slim Bound Photo Journal Album, Bella
# 89841          Baby Banz Hearing Protector Earmuffs, Blue
# 124076  The Door Guardian Childproofing Lock Colors: W...
#
#                                                    review  rating sentiment
# 181948  I got Freemie double electric pump (25mm cup) ...       1         0
# 153948  We got these to feed our now one year old son....       5         1
# 170450  I got this photo album to match the baby book ...       4         1
# 89841   These headphones are super cute but for me it ...       1         0
# 124076  We bought this lock because we didn't want to ...       5         1

# %%
df.tail()
# Out:
#                                                      name  \
# 169945           Gerber Washcloths, Gorilla, Boy, 6-Count
# 177254  Foscam FBM3501 Digital Video Baby Monitor - 2....
# 335                               Baby Trend Diaper Champ
# 82241         Cardinal Gates Stairway Special Gate, Black
# 34599                    Vulli Sophie the Giraffe Teether
#
#                                                    review  rating sentiment
# 169945  Nothing special,  thin material,  good enough ...       3         1
# 177254  Easy connection, excellent interface, good pic...       4         1
# 335     Our daughter is 13 months old and we've been u...       4         1
# 82241   This is our 2nd cardinal gate.  1st one is sti...       5         1
# 34599   What a great toy!  My 7 mo old just loves it! ...       5         1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54715 entries, 181948 to 34599
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       54715 non-null  object
#  1   review     54715 non-null  object
#  2   rating     54715 non-null  int64
#  3   sentiment  54715 non-null  category
# dtypes: category(1), int64(1), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# Droping here name and rating features as taking only review as feature

# %%
labels = df['sentiment']
features = df['review']

# %% [markdown]
# Create vector for fetaures for name and review to provide inputs to models

# %%
# Step 1: Convert text -> TF-IDF vectors
"""
If don't give max_feature then it will generate matix of
713248 - features - which is very large
"""
vectorizer = TfidfVectorizer(
    lowercase=True,
    ngram_range=(1, 2),     # unigrams + bigrams (captures "not good")
    max_features=5000       # cap vocabulary size
)
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size= 0.30, random_state= 123)
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
X_test_vec.shape
# Out:
# (16415, 5000)

# %%
X_train_vec.shape
# Out:
# (38300, 5000)

# %%
# To store accurray and F1Score of models for ploting and comparision
result = []

# %% [markdown]
# **Exercise 2**: **Implementation using K-Nearest Neighbor (KNN) Classifier**:  (2 point)
#
#
# [Refer to the Logistic Regression Example in the above cells]
#
# - Define the KNN classifier with Number of neighbours=5 using sklearn's **KNeighborsClassifier** function
# - Train the KNN classifier
# - Predict the test set
# - Calculate accuracy on the KNN classifier
# - Compute the F1 score

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_vec, y_train)
y_pred = knn.predict(X_test_vec)
knn_score = knn.score(X_test_vec, y_test)

# %%
print("Accuracy of the sentiment classification using the KNN based classifier: ", knn_score)
# Out:
# Accuracy of the sentiment classification using the KNN based classifier:  0.8563508985683825

# %%
knn_F1_score = f1_score(y_pred, y_test)
print("F1 Score for sentiment classification using the KNN based classifier: ", knn_F1_score)
# Out:
# F1 Score for sentiment classification using the KNN based classifier:  0.9226073257187869

# %%
result.append(["KNN",knn_score,knn_F1_score])

# %% [markdown]
# **Exercise 3**: **Implementation using Support Vector Machines (SVM) Classifier**:
#   - First Reduce the features using PCA
#   - use Hard-Margin Classifier
#   - use Soft-Margin Classifier
#   - use Kernel SVM Classifier
#
#
#
# Background:
# The next classifier we look into are support vector machines.
#
# ![wget](https://cdn.talentsprint.com/aiml/aiml_2020_b14_hyd/experiment_details_backup/linear_data.png)
#
# While the other classifiers such as the perceptron and the logistic regression uses a similar concept of finding a boundary between two classes using a straight line, SVMs aim to maximize this boundary. Therefore, not only the SVM tries to find a boundary, it tries to find the best boundary that separates the two classes. Again, with very simple tricks the two class classification can be easily extended to a multiclass classification. The formal formulation of a SVM is,
#
# $g(x) = w^Tx + b$, is the equation of the line we want to find with weights $w$ and a bias $b$.
#
# Now as seen from the figure, $g(x) = k$ and $g(x) = -k$ will give two worst lines for classification as they are right at the boundary of one of the classes. We need to maximize the distance of the line from both of the classes.
#
# Therefore,
#
# Maximize $k$ such that :
#
# $-w^Tx + b \geq k \: for \: d_i == 1$
#
# $-w^Tx + b \leq k \: for \: d_i == -1$
#
# We keep $g(x) \geq 1$ and minimize $||w||$.
#
# We finally write the final minimization function (uses Lagrangians to come to this solution).
#
# Minimize: $J(w, b, \alpha) = \frac{1}{2}w^Tw - \Sigma_{i=1}^{N}(\alpha_id_i(w^Tx_i + b)) + \Sigma_{i=1}^{N}(\alpha_i)$
#
# There are multiple types of SVM. We first use the standard linear SVM and check the performance of the model. However, SVM cannot be directly used on this dataset.

# %% [markdown]
# The data is too large and the normal SVM function from `sklearn` will take a lot of time to run. Therefore, we first apply a PCA based dimensionality reduction technique on the input data. This will be followed by different types of SVM techniques and the performance can be compared. Since, dimensionality reduction is applied, a slight drop in performance is expected. However, with the improvement in the time taken for training a SVM in mind, it is important we first apply PCA based dimensionality reduction.
#
# In principal component analysis, this relationship is quantified by finding a list of the principal axes in the data, and using those axes to describe the dataset.Using PCA for dimensionality reduction involves zeroing out one or more of the smallest principal components, resulting in a lower-dimensional projection of the data that preserves the maximal data variance.
#
#
# **Hints**
# - Define the PCA [Hint link PCA](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html) model using sklearn's **TruncatedSVD** [Hint link TruncatedSVD](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.TruncatedSVD.html)
# - Fit the training data using **model.fit**
# - Reduce the dimensions of the training data using **model.transform**
# - Reduce the dimensions of the testing data using **model.transform**
#
#
# - Use sklearn's **svm.SVC**. Appropriately choose the arguments - *kernel*, *gamma*, and *C* for hard-margin, soft-margin and kernel SVM classifiers. [Hint link SVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html)

# %% [markdown]
# Reducing features using PCA
# 1. Get vector matix for review features which has type as string - 5000 diemstion . We already got this is data preprosseing steps
# 2. Apply PCA on to reduce to dimension to 100

# %%
# Reduce to 100 dimensions
svd = TruncatedSVD(n_components=100, random_state=42)
X_train_svd = svd.fit_transform(X_train_vec)
X_test_svd = svd.transform(X_test_vec)

# %%
X_train_svd.shape
# Out:
# (38300, 100)

# %%
X_test_svd.shape
# Out:
# (16415, 100)

# %% [markdown]
# **Hard Margin**

# %%
# Approximate hard margin with very large C
hard_margin_svm = svm.SVC(kernel='linear', C=1e10,max_iter=10000)
hard_margin_svm.fit(X_train_svd, y_train)

y_pred = hard_margin_svm.predict(X_test_svd)
Hard_margin_svm_score = accuracy_score(y_test, y_pred)
print("Accuracy:", Hard_margin_svm_score)
Hard_margin_svm_f1_score = f1_score(y_test, y_pred)
print("F1 Score (hard margin approx):", Hard_margin_svm_f1_score)
# Out:
# Accuracy: 0.7566250380749314
# F1 Score (hard margin approx): 0.8577937564517851

# %%
result.append(["Hard Margin",Hard_margin_svm_score,Hard_margin_svm_f1_score])

# %% [markdown]
# **Soft Margin**

# %%
# C is the soft margin penalty parameter (in sklearn, SVC is ALWAYS soft margin by default)
soft_margin_svm = svm.SVC(kernel='linear', C=1.0, random_state=42,max_iter=10000)
soft_margin_svm.fit(X_train_svd, y_train)

y_pred = soft_margin_svm.predict(X_test_svd)
soft_margin_svm_score = accuracy_score(y_test, y_pred)
print("Accuracy:", soft_margin_svm_score)
soft_margin_svm_f1_score = f1_score(y_test, y_pred)
print("F1 Score (soft margin approx):", soft_margin_svm_f1_score)
result.append(["Soft Margin",soft_margin_svm_score,soft_margin_svm_f1_score])
# Out:
# Accuracy: 0.8858361254949741
# F1 Score (soft margin approx): 0.9367062955957849

# %% [markdown]
# **use Kernel SVM Classifier**

# %% [markdown]
# Try and error check with gamma and c values and see the accuracy

# %%
# Scale features (important for SVM with RBF kernel)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train_svd)
X_test = scaler.transform(X_test_svd)

# %%
svm_model = svm.SVC(kernel='rbf', gamma=0.1, C=1.0, random_state=42,max_iter=10000)
svm_model.fit(X_train, y_train)
y_pred = svm_model.predict(X_test)
Kernel_margin_svm_score = accuracy_score(y_test, y_pred)
print("Accuracy:", Kernel_margin_svm_score)
Kernel_margin_svm_f1_score = f1_score(y_test, y_pred)
print("F1 Score (kernel margin approx):", Kernel_margin_svm_f1_score)
result.append(["Kernel Margin",Kernel_margin_svm_score,Kernel_margin_svm_f1_score])
# Out:
# Accuracy: 0.8564118184587268
# F1 Score (kernel margin approx): 0.9226528402192105

# %% [markdown]
#    **Exercise 4**: **Implementation using Decision Trees**:  (2 point)
#
# Decision Trees are supervised Machine Learning algorithms that can perform both classification and regression tasks and even multioutput tasks. They can handle complex datasets. As the name shows, it uses a tree-like model to make decisions in order to classify or predict according to the problem. It is an ML algorithm that progressively divides datasets into smaller data groups based on a descriptive feature until it reaches sets that are small enough to be described by some label.
#
# The most important part of a decision tree is its explainability!
#
# The importance of decision tree algorithm is that it has many applications in the real world. For example:
#
# 1. In the Healthcare sector: To develop Clinical Decision Analysis tools which allow decision-makers to apply for evidence-based medicine and make objective clinical decisions when faced with complex situations.
# 2. Virtual Assistants (Chatbots): To develop chatbots that provide information and assistance to customers in any required domain.
# 3. Retail and Marketing: Sentiment analysis detects the pulse of customer feedback and emotions and allows organizations to learn about customer choices and drives decisions.
#
# **Hint**
# Use sklearn's **DecisionTreeClassifier** function

# %%
dt = DecisionTreeClassifier(max_depth=10,random_state=42)
dt.fit(X_train_vec, y_train)
y_pred = dt.predict(X_test_vec)
dt_score = dt.score(X_test_vec, y_test)
dt_f1 = f1_score(y_test, y_pred)
print("F1 Score:", dt_f1)
print("Accuracy:", dt_score)
result.append(["Decision Tree",dt_score,dt_f1])
# Out:
# F1 Score: 0.9305870795081134
# Accuracy: 0.8751751446847396

# %% [markdown]
# **Exercise 5**: **Implementation using Ensemble Classifier**:  (1 point)
# - use LogisticRegression, KNN, SVM, Naive Bayes and VotingClassifier as the weak classifiers
#
# [Hint link VotingClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html)

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import VotingClassifier

# %%
# Step 1: Convert text -> TF-IDF vectors
vectorizer = TfidfVectorizer(
    lowercase=True,
    stop_words='english',   # removes "the", "is", "and", etc.
    ngram_range=(1, 2),     # unigrams + bigrams (captures "not good")
    max_features=5000,      # cap vocabulary size
    min_df=1                # ignore terms that appear in fewer than N docs
)
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size= 0.30, random_state= 123)
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
# Reduce to 100 dimensions
svd = TruncatedSVD(n_components=100, random_state=42)
X_train_svd = svd.fit_transform(X_train_vec)
X_test_svd = svd.transform(X_test_vec)

# %%
# Instantiate LogisticRegression, KNN, SVC and VotingClassifier
log_clf = LogisticRegression()
knn_clf = KNN()
svm_clf = SVC(probability= True,max_iter=10000)
naviBays_clf = GaussianNB()
classifiers = [('lr', log_clf), ('knn', knn_clf), ('svc', svm_clf),('navie_bayes',naviBays_clf)]

voting_clf = VotingClassifier(estimators= classifiers, voting='soft')

for clf in (log_clf, knn_clf,svm_clf, naviBays_clf, voting_clf):
    clf.fit(X_train_svd, y_train)
    y_pred = clf.predict(X_test_svd)
    accuracy=accuracy_score(y_test, y_pred)
    f1  = f1_score(y_test, y_pred)
    result.append([clf.__class__.__name__,accuracy,f1])
    print(clf.__class__.__name__, accuracy)
    print(clf.__class__.__name__, f1)
# Out:
# LogisticRegression 0.8795004568991776
# LogisticRegression 0.933130493576741
# KNeighborsClassifier 0.833323180018276
# KNeighborsClassifier 0.904349042092015
# SVC 0.8865671641791045
# SVC 0.9369582881906826
# GaussianNB 0.7233627779469997
# GaussianNB 0.8199944503904547
# VotingClassifier 0.8780992994212611
# VotingClassifier 0.9307156954399086

# %% [markdown]
# **Exercise 6**: **Implementation using Clustering**: (2 point)
# - k Means Clustering, with and without PCA=2

# %%
# A helper function to help labelling the test predictions
def label(n_clusters, real_labels, labels):
    permutation=[]
    for i in range(n_clusters):
        idx = labels == i
        new_label=scipy.stats.mode(real_labels[idx])[0]  # Choose the most common label among data points in the cluster
        permutation.append(new_label)
    return permutation

# %%
#Without PCA
model = KMeans(2, random_state=42)
model.fit(X_train_vec)

# Assigning a label to each cluster
labelled_clusters = label(2, y_train, model.labels_)

# Calculating the train time accuracy
acc = accuracy_score(y_train, [ labelled_clusters[label] for label in model.labels_])
f1 = f1_score(y_train, [ labelled_clusters[label] for label in model.labels_])
result.append(["KMeans",acc,f1])
# This accuracy is for training.
print("Training accuracy score is", acc)
# Out:
# Training accuracy score is 0.855509138381201

# %%
print ("Mapping based on indices: ", labelled_clusters)
# Out:
# Mapping based on indices:  [np.int64(1), np.int64(1)]

# %%
#with PCA
model = KMeans(2, random_state=42)
model.fit(X_train_svd)

# Assigning a label to each cluster
labelled_clusters = label(2, y_train, model.labels_)

# Calculating the train time accuracy
acc = accuracy_score(y_train, [ labelled_clusters[label] for label in model.labels_])

# This accuracy is for training.
print("Training accuracy score is", acc)
# Out:
# Training accuracy score is 0.855509138381201

# %% [markdown]
# **Exercise 7**: **Test your own sentence**: (1 point)
# - Input your sentences ( One for positive and negative each)
# - Print the output sentiment.**Exercise**

# %% [markdown]
# **Positive Review**

# %%
# Step 1: New review text you want to classify
review1 = ["This product was good, very happy"]

# Step 2: Transform it using the SAME vectorizer (already fitted on training data)
review1_tfidf = vectorizer.transform(review1)

# Step 3: used dimensionality reduction, apply the same SVD transform
review1_svd = svd.transform(review1_tfidf)

# Step 4: Predict using your trained classifier
prediction = voting_clf.predict(review1_svd)

print("Prediction:", prediction[0])
print("Sentiment:", "Positive" if prediction[0] == 1 else "Negative")# YOUR CODE(s) HERE
# Out:
# Prediction: 1
# Sentiment: Positive

# %% [markdown]
# ** Negative Review **

# %%
# Step 1: review text you want to classify
review2 = ["This product broke after just two days, very disappointed"]

# Step 2: Transform it using the SAME vectorizer (already fitted on training data)
review2_tfidf = vectorizer.transform(review2)

# Step 3: used dimensionality reduction, apply the same SVD transform
review2_svd = svd.transform(review2_tfidf)

# Step 4: Predict using your trained classifier
prediction = voting_clf.predict(review2_svd)

print("Prediction:", prediction[0])
print("Sentiment:", "Positive" if prediction[0] == 1 else "Negative")# YOUR CODE(s) HERE
# Out:
# Prediction: 0
# Sentiment: Negative

# %% [markdown]
# Compare F1score and Accuray of KNN, Kmenas, Linear Regressing, Navie Bayes, SVM and Voting classifier

# %%
def plot_results(results_df, save_path="classifier_comparison.png"):
    """Plot a grouped bar chart comparing Accuracy and F1 Score."""
    names = results_df["Classifier"]
    acc = results_df["Accuracy"]
    f1 = results_df["F1 Score"]

    x = np.arange(len(names))
    width = 0.35

    fig, ax = plt.subplots(figsize=(10, 6))
    bars1 = ax.bar(x - width / 2, acc, width, label="Accuracy", color="#4C72B0")
    bars2 = ax.bar(x + width / 2, f1, width, label="F1 Score", color="#DD8452")

    ax.set_ylabel("Score")
    ax.set_title("Classifier Comparison: Accuracy vs F1 Score")
    ax.set_xticks(x)
    ax.set_xticklabels(names, rotation=30, ha="right")
    ax.set_ylim(0, 1.05)
    ax.legend()
    ax.bar_label(bars1, fmt="%.3f", padding=2, fontsize=8)
    ax.bar_label(bars2, fmt="%.3f", padding=2, fontsize=8)

    plt.tight_layout()
    plt.savefig(save_path, dpi=150)
    plt.show()
    print(f"\nChart saved to: {save_path}")

# %%
result_df = pd.DataFrame(result, columns=["Classifier", "Accuracy", "F1 Score"])
plot_results(result_df)
# Out:
# Chart saved to: classifier_comparison.png
